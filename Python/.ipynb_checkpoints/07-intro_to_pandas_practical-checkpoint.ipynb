# %% [markdown]
# A practical introduction to Pandas
# ===================

# %% [markdown]
# We have been asked to *analyze an otp dataset*, without much more information. This kind of scenario is more common than you might imagine!
#
# ## 1) Quickly examine the files in ~/Data/us_dot/otp. What do they contain, in both technical and functional terms? (Use any tool you want)

# %%
path_to_files = '/home/dsc/Data/us_dot/otp/'

! ls -l {path_to_files}
# Out:
# total 167704
# -rw-r--r--. 1 dsc dsc 21230105 Nov  8  2015 On_Time_On_Time_Performance_2015_2.zip
# -rw-r--r--. 1 dsc dsc 24811186 Nov  8  2015 On_Time_On_Time_Performance_2015_3.zip
# -rw-r--r--. 1 dsc dsc 23625261 Nov  8  2015 On_Time_On_Time_Performance_2015_4.zip
# -rw-r--r--. 1 dsc dsc 24334057 Nov  8  2015 On_Time_On_Time_Performance_2015_5.zip
# -rw-r--r--. 1 dsc dsc 25758350 Nov  8  2015 On_Time_On_Time_Performance_2015_6.zip
# -rw-r--r--. 1 dsc dsc 26204213 Nov  8  2015 On_Time_On_Time_Performance_2015_7.zip
# -rw-r--r--. 1 dsc dsc 25726054 Nov  8  2015 On_Time_On_Time_Performance_2015_8.zip

# %% [markdown]
# For this example, we are going to begin using the shell from within this notebook, with the ! notation:
#
# A ! sign before a line tells the notebook to send that line straight away to the underlying OS.
#
# \* Note that we can substitute python variables into the shell command. We do that by surrounding the name of the variable with curly braces ({}). That's what we are going to do with the `path_to_files` variable

# %% [markdown]
# ### Check what the files contain

# %%
filename = 'On_Time_On_Time_Performance_2015_2.zip'

! unzip -l {path_to_files + filename}
# Out:
# Archive:  /home/dsc/Data/us_dot/otp/On_Time_On_Time_Performance_2015_2.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
# 192791767  04-16-2015 20:03   On_Time_On_Time_Performance_2015_2.csv
#     12054  04-16-2015 20:02   readme.html
# ---------                     -------
# 192803821                     2 files

# %% [markdown]
# Oh, it has a readme! Always good to read it.

# %% [markdown]
# ### Unzip the readme to the current directory

# %%
! unzip {path_to_files + filename} readme.html
# Out:
# Archive:  /home/dsc/Data/us_dot/otp/On_Time_On_Time_Performance_2015_2.zip
#   inflating: readme.html

# %%
# !ls -l
# Out:
# total 2960
# -rw-rw-r-- 1 dsc dsc  141776 Nov 25 09:55 02-loading_and_saving_data.ipynb
# -rw-rw-r-- 1 dsc dsc   61204 Nov 25 11:40 03-merge_concatenate_transform.ipynb
# -rw-rw-r-- 1 dsc dsc   70786 Nov 25 12:36 04-group_by.ipynb
# -rw-rw-r-- 1 dsc dsc 1546558 Nov 17 13:36 05-visualization_introduction.ipynb
# -rw-rw-r-- 1 dsc dsc  336361 Dec  1 18:27 06-ejercicios_de_repaso_de_pandas.ipynb
# -rw-rw-r-- 1 dsc dsc   72779 Dec  6 12:18 07-intro_to_pandas_practical.ipynb
# -rw-rw-r-- 1 dsc dsc   31332 Nov 29 18:25 09-web_apis_and_scraping_101.ipynb
# -rw-rw-r-- 1 dsc dsc   49926 Nov 25 09:14 accidentes.xls
# -rw-rw-r-- 1 dsc dsc    4324 Dec  1 21:43 ch_01_blank.ipynb
# -rw-rw-r-- 1 dsc dsc   52080 Dec  1 21:43 ch_02_blank.ipynb
# -rw-rw-r-- 1 dsc dsc    4723 Dec  1 15:07 ch_03_blank.ipynb
# drwxrwxr-x 2 dsc dsc    4096 Nov  4 16:45 __pycache__
# -rw-rw-r-- 1 dsc dsc  225020 Nov 29 18:15 python_scipy_np_pandas_01.ipynb
# -rw-rw-r-- 1 dsc dsc   74577 Nov 16 23:55 python_session1.ipynb
# -rw-rw-r-- 1 dsc dsc   42910 Nov 18 10:39 python_session2.ipynb
# -rw-rw-r-- 1 dsc dsc  245689 Nov 24 19:55 python_session3.ipynb
# -rw-r--r-- 1 dsc dsc   12054 Apr 16  2015 readme.html
# -rw-rw-r-- 1 dsc dsc     103 Nov  4 16:43 some_module.py
# -rw-rw-r-- 1 dsc dsc    7943 Nov 25 11:57 tips.csv
# -rw-rw-r-- 1 dsc dsc    8849 Nov 25 09:16 Untitled.ipynb

# %% [markdown]
# The readme file is html. Luckily, we are working in an html environment.
#
# ### Display the contents of `readme.html` within the notebook
# (Hint: check out [IPython.display.IFrame](https://ipython.org/ipython-doc/3/api/generated/IPython.display.html))

# %%
import IPython.display as dsp

html = 'readme.html'

dsp.IFrame(html,900,300)
# Out:
#         <iframe
#             width="900"
#             height="300"
#             src="readme.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
! rm readme.html

# %% [markdown]
# That's some very good documentation!
#
# ### Summary:
#
# The files within the zip are " quoted csv's. They contain information on timeliness of departures in the US, at the departure level.

# %%
! zcat {path_to_files+filename} {filename[:-3] +'csv'} | head
# Out:
# "Year","Quarter","Month","DayofMonth","DayOfWeek","FlightDate","UniqueCarrier","AirlineID","Carrier","TailNum","FlightNum","OriginAirportID","OriginAirportSeqID","OriginCityMarketID","Origin","OriginCityName","OriginState","OriginStateFips","OriginStateName","OriginWac","DestAirportID","DestAirportSeqID","DestCityMarketID","Dest","DestCityName","DestState","DestStateFips","DestStateName","DestWac","CRSDepTime","DepTime","DepDelay","DepDelayMinutes","DepDel15","DepartureDelayGroups","DepTimeBlk","TaxiOut","WheelsOff","WheelsOn","TaxiIn","CRSArrTime","ArrTime","ArrDelay","ArrDelayMinutes","ArrDel15","ArrivalDelayGroups","ArrTimeBlk","Cancelled","CancellationCode","Diverted","CRSElapsedTime","ActualElapsedTime","AirTime","Flights","Distance","DistanceGroup","CarrierDelay","WeatherDelay","NASDelay","SecurityDelay","LateAircraftDelay","FirstDepTime","TotalAddGTime","LongestAddGTime","DivAirportLandings","DivReachedDest","DivActualElapsedTime","DivArrDelay","DivDistance","Div1Airport","Div1AirportID","Div1AirportSeqID","Div1WheelsOn","Div1TotalGTime","Div1LongestGTime","Div1WheelsOff","Div1TailNum","Div2Airport","Div2AirportID","Div2AirportSeqID","Div2WheelsOn","Div2TotalGTime","Div2LongestGTime","Div2WheelsOff","Div2TailNum","Div3Airport","Div3AirportID","Div3AirportSeqID","Div3WheelsOn","Div3TotalGTime","Div3LongestGTime","Div3WheelsOff","Div3TailNum","Div4Airport","Div4AirportID","Div4AirportSeqID","Div4WheelsOn","Div4TotalGTime","Div4LongestGTime","Div4WheelsOff","Div4TailNum","Div5Airport","Div5AirportID","Div5AirportSeqID","Div5WheelsOn","Div5TotalGTime","Div5LongestGTime","Div5WheelsOff","Div5TailNum",
# 2015,1,2,7,6,2015-02-07,"AS",19930,"AS","N618AS","131",14057,1405702,34057,"PDX","Portland, OR","OR","41","Oregon",92,10299,1029904,30299,"ANC","Anchorage, AK","AK","02","Alaska",1,"0940","0959",19.00,19.00,1.00,1,"0900-0959",10.00,"1009","1224",3.00,"1239","1227",-12.00,0.00,0.00,-1,"1200-1259",0.00,"",0.00,239.00,208.00,195.00,1.00,1542.00,7,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2015,1,2,7,6,2015-02-07,"AS",19930,"AS","N778AS","132",11630,1163002,31517,"FAI","Fairbanks, AK","AK","02","Alaska",1,14747,1474703,30559,"SEA","Seattle, WA","WA","53","Washington",93,"1730","1717",-13.00,0.00,0.00,-1,"1700-1759",9.00,"1726","2143",6.00,"2205","2149",-16.00,0.00,0.00,-2,"2200-2259",0.00,"",0.00,215.00,212.00,197.00,1.00,1533.00,7,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2015,1,2,7,6,2015-02-07,"AS",19930,"AS","N586AS","140",10299,1029904,30299,"ANC","Anchorage, AK","AK","02","Alaska",1,14057,1405702,34057,"PDX","Portland, OR","OR","41","Oregon",92,"1140","1132",-8.00,0.00,0.00,-1,"1100-1159",13.00,"1145","1557",3.00,"1608","1600",-8.00,0.00,0.00,-1,"1600-1659",0.00,"",0.00,208.00,208.00,192.00,1.00,1542.00,7,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2015,1,2,7,6,2015-02-07,"AS",19930,"AS","N615AS","143",14057,1405702,34057,"PDX","Portland, OR","OR","41","Oregon",92,10299,1029904,30299,"ANC","Anchorage, AK","AK","02","Alaska",1,"2210","2201",-9.00,0.00,0.00,-1,"2200-2259",10.00,"2211","0024",4.00,"0103","0028",-35.00,0.00,0.00,-2,"0001-0559",0.00,"",0.00,233.00,207.00,193.00,1.00,1542.00,7,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2015,1,2,7,6,2015-02-07,"AS",19930,"AS","N471AS","149",12892,1289203,32575,"LAX","Los Angeles, CA","CA","06","California",91,10299,1029904,30299,"ANC","Anchorage, AK","AK","02","Alaska",1,"1940","1941",1.00,1.00,0.00,0,"1900-1959",13.00,"1954","2343",6.00,"0025","2349",-36.00,0.00,0.00,-2,"0001-0559",0.00,"",0.00,345.00,308.00,289.00,1.00,2345.00,10,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2015,1,2,7,6,2015-02-07,"AS",19930,"AS","N535AS","150",10299,1029904,30299,"ANC","Anchorage, AK","AK","02","Alaska",1,12892,1289203,32575,"LAX","Los Angeles, CA","CA","06","California",91,"2340","2331",-9.00,0.00,0.00,-1,"2300-2359",16.00,"2347","0541",6.00,"0600","0547",-13.00,0.00,0.00,-1,"0600-0659",0.00,"",0.00,320.00,316.00,294.00,1.00,2345.00,10,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2015,1,2,7,6,2015-02-07,"AS",19930,"AS","N764AS","151",10299,1029904,30299,"ANC","Anchorage, AK","AK","02","Alaska",1,13873,1387302,33873,"OME","Nome, AK","AK","02","Alaska",1,"1025","1052",27.00,27.00,1.00,1,"1000-1059",8.00,"1100","1212",7.00,"1159","1219",20.00,20.00,1.00,1,"1100-1159",0.00,"",0.00,94.00,87.00,72.00,1.00,539.00,3,0.00,0.00,0.00,0.00,20.00,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2015,1,2,7,6,2015-02-07,"AS",19930,"AS","N764AS","152",13873,1387302,33873,"OME","Nome, AK","AK","02","Alaska",1,10299,1029904,30299,"ANC","Anchorage, AK","AK","02","Alaska",1,"1253","1257",4.00,4.00,0.00,0,"1200-1259",8.00,"1305","1427",3.00,"1420","1430",10.00,10.00,0.00,0,"1400-1459",0.00,"",0.00,87.00,93.00,82.00,1.00,539.00,3,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
# 2015,1,2,7,6,2015-02-07,"AS",19930,"AS","N768AS","153",13970,1397002,33970,"OTZ","Kotzebue, AK","AK","02","Alaska",1,13873,1387302,33873,"OME","Nome, AK","AK","02","Alaska",1,"1900","1902",2.00,2.00,0.00,0,"1900-1959",13.00,"1915","1947",2.00,"1942","1949",7.00,7.00,0.00,0,"1900-1959",0.00,"",0.00,42.00,47.00,32.00,1.00,183.00,1,,,,,,"",,,0,,,,,"",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","","",,,"",,,"","",
#
# gzip: stdout: Broken pipe

# %% [markdown]
# Pretty unreadable, so we go for a tool designed specifically for tabular data: **pandas**

# %% [markdown]
# ### Load some of the data (one of the files) into memory as a pandas dataframe. What functions do you need to use?
#
# Pro tip: there is no need to decompress the whole file.

# %% [markdown]
# First, open a connection to one of the files

# %%
import zipfile
zip_file = zipfile.ZipFile(path_to_files+filename)

# %%
zip_file.filelist
# Out:
# [<ZipInfo filename='On_Time_On_Time_Performance_2015_2.csv' compress_type=deflate filemode='-rw-r--r--' file_size=192791767 compress_size=21227521>,
#  <ZipInfo filename='readme.html' compress_type=deflate filemode='-rw-r--r--' file_size=12054 compress_size=2208>]

# %% [markdown]
# zip_file is a connection to the compressed file, the .zip. We can use it to open a connection to one of the files it contains, which will behave like a normal uncompressed file that we had opened with open()

# %%
csv, html = zip_file.filelist
csv_file = zip_file.open(csv.filename)

# %%
import pandas as pd
df = pd.read_csv(csv_file)
# Out:
# /home/dsc/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Now we're ready to load the file into memory as a pandas dataframe. Remember to close the connections to the files!

# %%
zip_file.close()
csv_file.close()

# %% [markdown]
# Let's start examining the data: show the beginning of the file. How many records does it contain?

# %%
df.shape
# Out:
# (429191, 110)

# %% [markdown]
# ## Trimming the data
#
# The table is quite wide, and it seems that there are many columns without much data. Which, exactly, are those? (let's consider empty a column that doesn't contain at least 1000 records, arbitrarily)

# %%
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0  2015        1      2           7          6  2015-02-07            AS
# 1  2015        1      2           7          6  2015-02-07            AS
# 2  2015        1      2           7          6  2015-02-07            AS
# 3  2015        1      2           7          6  2015-02-07            AS
# 4  2015        1      2           7          6  2015-02-07            AS
#
#    AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 0      19930      AS  N618AS      ...               NaN          NaN
# 1      19930      AS  N778AS      ...               NaN          NaN
# 2      19930      AS  N586AS      ...               NaN          NaN
# 3      19930      AS  N615AS      ...               NaN          NaN
# 4      19930      AS  N471AS      ...               NaN          NaN
#
#    Div5AirportID  Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# 0            NaN               NaN          NaN            NaN
# 1            NaN               NaN          NaN            NaN
# 2            NaN               NaN          NaN            NaN
# 3            NaN               NaN          NaN            NaN
# 4            NaN               NaN          NaN            NaN
#
#   Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0              NaN            NaN         NaN           NaN
# 1              NaN            NaN         NaN           NaN
# 2              NaN            NaN         NaN           NaN
# 3              NaN            NaN         NaN           NaN
# 4              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %%
df.columns[df.count() < 1000]
# Out:
# Index(['DivActualElapsedTime', 'DivArrDelay', 'Div1WheelsOff', 'Div1TailNum',
#        'Div2Airport', 'Div2AirportID', 'Div2AirportSeqID', 'Div2WheelsOn',
#        'Div2TotalGTime', 'Div2LongestGTime', 'Div2WheelsOff', 'Div2TailNum',
#        'Div3Airport', 'Div3AirportID', 'Div3AirportSeqID', 'Div3WheelsOn',
#        'Div3TotalGTime', 'Div3LongestGTime', 'Div3WheelsOff', 'Div3TailNum',
#        'Div4Airport', 'Div4AirportID', 'Div4AirportSeqID', 'Div4WheelsOn',
#        'Div4TotalGTime', 'Div4LongestGTime', 'Div4WheelsOff', 'Div4TailNum',
#        'Div5Airport', 'Div5AirportID', 'Div5AirportSeqID', 'Div5WheelsOn',
#        'Div5TotalGTime', 'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum',
#        'Unnamed: 109'],
#       dtype='object')

# %% [markdown]
# It seems that the "diverted" fields, after the first, are often empty. No big surprise, since not that many flights must be diverted more than once in a month. Let's drop those columns, since we are not that interested in those, at least for now.

# %%
df2 = df.drop(df.columns[df.count() < 1000], axis = 1)

# %% [markdown]
# Now that we have eliminated some inconvenient data columns, let's have a look at the rest:

# %% [markdown]
# Let's loook at how the location data is encoded.
#
# ### Select the columns that have 'Origin' in their name
#
# Hint: we are going to use the str attribute of Series and Indexes

# %%
list_origin = df2.columns[df2.columns.str.contains('Origin')]
list_origin
# Out:
# Index(['OriginAirportID', 'OriginAirportSeqID', 'OriginCityMarketID', 'Origin',
#        'OriginCityName', 'OriginState', 'OriginStateFips', 'OriginStateName',
#        'OriginWac'],
#       dtype='object')

# %% [markdown]
# Let's now have a look at these. We have been using the .head() method, but that always returns the same values, so it's not that good for getting a feel for the data. Let's start using a better one, that will give us a sample of the data: df.sample()

# %%
df2[list_origin].sample(10)
# Out:
#         OriginAirportID  OriginAirportSeqID  OriginCityMarketID Origin  \
# 167023            11697             1169703               32467    FLL
# 16145             12953             1295302               31703    LGA
# 119726            13851             1385103               33851    OKC
# 303221            12892             1289203               32575    LAX
# 174504            12478             1247802               31703    JFK
# 378472            12953             1295302               31703    LGA
# 26018             11259             1125903               30194    DAL
# 3549              12478             1247802               31703    JFK
# 215188            14107             1410702               30466    PHX
# 340561            13158             1315802               33158    MAF
#
#              OriginCityName OriginState  OriginStateFips OriginStateName  \
# 167023  Fort Lauderdale, FL          FL               12         Florida
# 16145          New York, NY          NY               36        New York
# 119726    Oklahoma City, OK          OK               40        Oklahoma
# 303221      Los Angeles, CA          CA                6      California
# 174504         New York, NY          NY               36        New York
# 378472         New York, NY          NY               36        New York
# 26018            Dallas, TX          TX               48           Texas
# 3549           New York, NY          NY               36        New York
# 215188          Phoenix, AZ          AZ                4         Arizona
# 340561   Midland/Odessa, TX          TX               48           Texas
#
#         OriginWac
# 167023         33
# 16145          22
# 119726         73
# 303221         91
# 174504         22
# 378472         22
# 26018          74
# 3549           22
# 215188         81
# 340561         74

# %% [markdown]
# #### Exercise:
#
# Show all airport codes in NY city and Washington DC.

# %%
print(df2[df2['OriginCityName'].str.contains('New York')]['Origin'].unique())
print(df2[df2['OriginCityName'].str.contains('Washington')]['Origin'].unique())
# Out:
# ['LGA' 'JFK']
# ['DCA' 'IAD']

# %% [markdown]
# So much redundant information!!!!! Let's drop a few of those fields. Remember, 90% of the time spent in Data Science is data cleaning...

# %% [markdown]
# ### Do the same for the destination columns

# %%
list_dest = df2.columns[df2.columns.str.contains('Dest')]
list_dest
# Out:
# Index(['DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'Dest',
#        'DestCityName', 'DestState', 'DestStateFips', 'DestStateName',
#        'DestWac', 'DivReachedDest'],
#       dtype='object')

# %% [markdown]
# ### Now, discard all these columns with redundant information.
#
# The set of columns we want to discard is
#
# `df.columns[col_contains_dest] + df.columns[col_contains_origin] - columns_of_interest`
#
# We'll also use the opportunity to drop Year, Month, Day and Quarter columns since that is information that is already contained in FlightDate. We'll keep the DayOfWeek, though.

# %%
columns_of_interest = pd.Index(['Origin', 'OriginCityName', 'OriginStateName', 'Dest', 'DestCityName', 'DestStateName'])

# %%
column_dates = pd.Index(['Year','Month', 'DayofMonth'])

cols_to_drop = list_dest | list_origin
cols_to_drop = cols_to_drop | column_dates
cols_to_drop = cols_to_drop.difference(columns_of_interest)
cols_to_drop
# Out:
# Index(['DayofMonth', 'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID',
#        'DestState', 'DestStateFips', 'DestWac', 'DivReachedDest', 'Month',
#        'OriginAirportID', 'OriginAirportSeqID', 'OriginCityMarketID',
#        'OriginState', 'OriginStateFips', 'OriginWac', 'Year'],
#       dtype='object')

# %%
df3 = df2.drop(cols_to_drop, axis = 1)

# %%
df3.shape
# Out:
# (429191, 57)

# %% [markdown]
# OK, so we have cleaned up most of the date / location information,  and some of the extra information that was not really useful, in the process reducing the dataframe from 110 columns to 60. Let's look at the really interesting info: delays.

# %% [markdown]
# ## Fast forward

# %% [markdown]
# All of this is getting a little repetitive and boring, so let's just specify the columns we want:

# %%
df = df[['FlightDate', 'DayOfWeek', 'Carrier', 'TailNum', 'FlightNum', 'Origin', 
         'OriginCityName', 'OriginStateName', 'Dest', 'DestCityName', 'DestStateName',
         'DepTime', 'DepDelay', 'AirTime', 'Distance']]
df.sample(5)
# Out:
#         FlightDate  DayOfWeek Carrier TailNum  FlightNum Origin  \
# 233453  2015-02-18          3      UA  N410UA        580    SFO
# 354840  2015-02-12          4      OO  N802SK       4804    PHX
# 10811   2015-02-22          7      DL  N901DA       2452    RIC
# 65478   2015-02-05          4      EV  N14105       6157    CID
# 262904  2015-02-11          3      WN  N7733B        360    BUR
#
#                     OriginCityName OriginStateName Dest   DestCityName  \
# 233453           San Francisco, CA      California  PHX    Phoenix, AZ
# 354840                 Phoenix, AZ         Arizona  SEA    Seattle, WA
# 10811                 Richmond, VA        Virginia  ATL    Atlanta, GA
# 65478   Cedar Rapids/Iowa City, IA            Iowa  ORD    Chicago, IL
# 262904                 Burbank, CA      California  LAS  Las Vegas, NV
#
#        DestStateName  DepTime  DepDelay  AirTime  Distance
# 233453       Arizona   1233.0      -7.0     89.0     651.0
# 354840    Washington   1857.0      -9.0    162.0    1107.0
# 10811        Georgia   1221.0      16.0     88.0     481.0
# 65478       Illinois    805.0      -5.0     38.0     196.0
# 262904        Nevada   1405.0      15.0     43.0     223.0

# %% [markdown]
# ## Formatting columns and parsing dates and times
#
# Hurray! we have almost cleaned our dataset. Soon we will begin to do some actual work with it.

# %%
df['DepTime'].dtype
# Out:
# dtype('float64')

# %%
df['FlightDate'].dtype
# Out:
# dtype('O')

# %% [markdown]
# Pandas interpreted the Deptime column as ints and the FlighDate column as strings. We want to combine them and parse them into a DateTime column, so that we can use them properly as datetimes.

# %% [markdown]
# First,
#
# ### Define a function that will parse our int hours into a reasonable format ("HH:MM")

# %%
import numpy as np
def to_hour(deptime):
    ### Take the Deptime and transform it to minutes
    try:    
        hour = int(deptime/100)
        minute = int(deptime-(hour*100))
        if hour<10:
            str_hour = '0' + str(hour)
        else:
            str_hour = str(hour)
        if minute<10:
            str_min = '0' + str(minute)
        else:
            str_min = str(minute)

        return str_hour + ':' + str_min
    except ValueError :
        return '00:00'
        
print(to_hour(955.0))
print(to_hour(4.0))
print(to_hour(0.0))
print(to_hour(1325.0))
print(to_hour(np.nan))
# Out:
# 09:55
# 00:04
# 00:00
# 13:25
# 00:00

# %% [markdown]
# Now, we can use that function to build datetime strings that we will then pass to pd.to_datetime, with a format we will specify. Let's do that
#
# Hint: Check out [pd.to_datetime's documentatoin](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html) for info on the acceptable format.

# %% [markdown]
# ### Overwrite the 'DepTime' column with its version in the proper format
#
# Hint: Before overwriting your column in the dataframe, make sure that everything works by assigning the modified column to a Series variable.

# %%
test_deptime = df['DepTime'].apply(to_hour)
test_deptime
# Out:
# 0         09:59
# 1         17:17
# 2         11:32
# 3         22:01
# 4         19:41
# 5         23:31
# 6         10:52
# 7         12:57
# 8         19:02
# 9         16:46
# 10        20:30
# 11        08:36
# 12        06:26
# 13        05:53
# 14        23:32
# 15        18:20
# 16        09:44
# 17        05:52
# 18        17:34
# 19        07:54
# 20        20:57
# 21        06:26
# 22        16:58
# 23        20:26
# 24        19:46
# 25        06:34
# 26        08:07
# 27        08:47
# 28        18:06
# 29        19:07
#           ...
# 429161    12:46
# 429162    09:27
# 429163    11:47
# 429164    12:16
# 429165    00:00
# 429166    11:17
# 429167    11:17
# 429168    11:20
# 429169    11:21
# 429170    11:21
# 429171    11:20
# 429172    11:22
# 429173    11:40
# 429174    11:34
# 429175    11:31
# 429176    11:50
# 429177    12:37
# 429178    13:03
# 429179    12:36
# 429180    12:34
# 429181    12:37
# 429182    00:00
# 429183    12:54
# 429184    13:13
# 429185    12:48
# 429186    12:44
# 429187    13:48
# 429188    05:55
# 429189    05:55
# 429190    09:16
# Name: DepTime, Length: 429191, dtype: object

# %%
df['DepTime'] = df['DepTime'].apply(to_hour)

# %%
df.sample(5)
# Out:
#         FlightDate  DayOfWeek Carrier TailNum  FlightNum Origin  \
# 180522  2015-02-04          3      DL  N607AT       2120    MDW
# 289500  2015-02-20          5      WN  N603SW       3206    SMF
# 364026  2015-02-22          7      OO  N120SY       6355    MSP
# 232096  2015-02-01          7      WN  N365SW       3768    SAN
# 421398  2015-02-16          1      US  N801AW       1840    CLT
#
#          OriginCityName OriginStateName Dest       DestCityName DestStateName  \
# 180522      Chicago, IL        Illinois  ATL        Atlanta, GA       Georgia
# 289500   Sacramento, CA      California  PDX       Portland, OR        Oregon
# 364026  Minneapolis, MN       Minnesota  ORD        Chicago, IL      Illinois
# 232096    San Diego, CA      California  SFO  San Francisco, CA    California
# 421398    Charlotte, NC  North Carolina  PIT     Pittsburgh, PA  Pennsylvania
#
#        DepTime  DepDelay  AirTime  Distance
# 180522   09:39     -12.0     87.0     591.0
# 289500   21:33      23.0     79.0     479.0
# 364026   15:53       6.0     51.0     334.0
# 232096   13:20      -5.0     72.0     447.0
# 421398   18:55      50.0     63.0     366.0

# %% [markdown]
# ### Now, create a DepDateTime with the proper type using `pd.to_datetime`

# %%
df['DepDateTime'] = df['FlightDate'] + ' ' + df['DepTime'] + ':00'
df.sample(5)

df['DepDateTime2'] = pd.to_datetime(df['DepDateTime'], errors = 'coerce')

# %%
df.sample(5)
# Out:
#         FlightDate  DayOfWeek Carrier TailNum  FlightNum Origin  \
# 212297  2015-02-18          3      DL  N944DL       1077    ATL
# 158493  2015-02-11          3      B6  N583JB        271    LGA
# 191737  2015-02-09          1      DL  N37700        395    SJU
# 239201  2015-02-03          2      WN  N447WN       1263    SNA
# 278157  2015-02-16          1      WN  N651SW       1517    SAN
#
#        OriginCityName OriginStateName Dest         DestCityName  \
# 212297    Atlanta, GA         Georgia  RDU   Raleigh/Durham, NC
# 158493   New York, NY        New York  FLL  Fort Lauderdale, FL
# 191737   San Juan, PR     Puerto Rico  JFK         New York, NY
# 239201  Santa Ana, CA      California  PHX          Phoenix, AZ
# 278157  San Diego, CA      California  PHX          Phoenix, AZ
#
#          DestStateName DepTime  DepDelay  AirTime  Distance  \
# 212297  North Carolina   14:17      22.0     56.0     356.0
# 158493         Florida   09:33       3.0    149.0    1076.0
# 191737        New York   12:54      -1.0    203.0    1598.0
# 239201         Arizona   16:04       4.0     54.0     338.0
# 278157         Arizona   12:53      13.0     53.0     304.0
#
#                 DepDateTime        DepDateTime2
# 212297  2015-02-18 14:17:00 2015-02-18 14:17:00
# 158493  2015-02-11 09:33:00 2015-02-11 09:33:00
# 191737  2015-02-09 12:54:00 2015-02-09 12:54:00
# 239201  2015-02-03 16:04:00 2015-02-03 16:04:00
# 278157  2015-02-16 12:53:00 2015-02-16 12:53:00

# %%
df['DepDateTime'] = df['DepDateTime2']
df['DepDateTime'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.dtypes
# Out:
# FlightDate                 object
# DayOfWeek                   int64
# Carrier                    object
# TailNum                    object
# FlightNum                   int64
# Origin                     object
# OriginCityName             object
# OriginStateName            object
# Dest                       object
# DestCityName               object
# DestStateName              object
# DepTime                    object
# DepDelay                  float64
# AirTime                   float64
# Distance                  float64
# DepDateTime        datetime64[ns]
# DepDateTime2       datetime64[ns]
# dtype: object

# %% [markdown]
# ### Transform the FlightNum column into a column of strings
#
# Because flight numbers are actually names, not numbers: we won't do arithmetic on them. It wouldn't make sense to receive summary statistics on the `FlightNum` column with `.describe()`, for example.

# %%
df['FlightNum2'] = df['FlightNum'].map(str)

# %%
df.head()
# Out:
#    FlightDate  DayOfWeek Carrier TailNum  FlightNum Origin   OriginCityName  \
# 0  2015-02-07          6      AS  N618AS        131    PDX     Portland, OR
# 1  2015-02-07          6      AS  N778AS        132    FAI    Fairbanks, AK
# 2  2015-02-07          6      AS  N586AS        140    ANC    Anchorage, AK
# 3  2015-02-07          6      AS  N615AS        143    PDX     Portland, OR
# 4  2015-02-07          6      AS  N471AS        149    LAX  Los Angeles, CA
#
#   OriginStateName Dest   DestCityName DestStateName DepTime  DepDelay  \
# 0          Oregon  ANC  Anchorage, AK        Alaska   09:59      19.0
# 1          Alaska  SEA    Seattle, WA    Washington   17:17     -13.0
# 2          Alaska  PDX   Portland, OR        Oregon   11:32      -8.0
# 3          Oregon  ANC  Anchorage, AK        Alaska   22:01      -9.0
# 4      California  ANC  Anchorage, AK        Alaska   19:41       1.0
#
#    AirTime  Distance         DepDateTime        DepDateTime2 FlightNum2
# 0    195.0    1542.0 2015-02-07 09:59:00 2015-02-07 09:59:00        131
# 1    197.0    1533.0 2015-02-07 17:17:00 2015-02-07 17:17:00        132
# 2    192.0    1542.0 2015-02-07 11:32:00 2015-02-07 11:32:00        140
# 3    193.0    1542.0 2015-02-07 22:01:00 2015-02-07 22:01:00        143
# 4    289.0    2345.0 2015-02-07 19:41:00 2015-02-07 19:41:00        149

# %%
df = df.drop(['FlightDate','DepTime','DepDateTime2','FlightNum'], axis = 1)

# %% [markdown]
# ## Examining the data

# %% [markdown]
# Finally clean! Let's start to do some preliminary work on the data.

# %% [markdown]
# ### Find the biggest delays.
#
# How would you find the 5 maximum delays?

# %%
df.sort_values(by = 'DepDelay', ascending =False).iloc[0:5]
# Out:
#         DayOfWeek Carrier TailNum Origin OriginCityName OriginStateName Dest  \
# 126203          6      AA  N028AA    STL  St. Louis, MO        Missouri  MIA
# 117050          7      AA  N007AA    EGE      Eagle, CO        Colorado  ORD
# 73864           7      HA  N374HA    HNL   Honolulu, HI          Hawaii  JFK
# 73885           1      HA  N374HA    JFK   New York, NY        New York  HNL
# 131625          4      AA  N3ASAA    PHX    Phoenix, AZ         Arizona  ORD
#
#         DestCityName DestStateName  DepDelay  AirTime  Distance  \
# 126203     Miami, FL       Florida    1587.0    131.0    1068.0
# 117050   Chicago, IL      Illinois    1457.0    123.0    1007.0
# 73864   New York, NY      New York    1433.0    498.0    4983.0
# 73885   Honolulu, HI        Hawaii    1429.0    684.0    4983.0
# 131625   Chicago, IL      Illinois    1367.0    167.0    1440.0
#
#                DepDateTime FlightNum2
# 126203 2015-02-28 08:47:00       1312
# 117050 2015-02-22 14:32:00       1080
# 73864  2015-02-08 16:23:00         50
# 73885  2015-02-09 09:24:00         51
# 131625 2015-02-19 05:54:00       1564

# %% [markdown]
# ### What was the average delay for this month? Standard deviation and typical value?

# %%
date_init = pd.to_datetime('2015/02/01 00:00:00')
date_fin = pd.to_datetime('2015/02/28 00:00:00')
condition = (df['DepDateTime'] > date_init) & (df['DepDateTime'] < date_fin)

df[condition].describe()
# Out:
#            DayOfWeek       DepDelay        AirTime       Distance
# count  414340.000000  397385.000000  395965.000000  414340.000000
# mean        3.822926      11.857038     112.399250     799.816590
# std         1.964439      40.019583      71.656292     591.239008
# min         1.000000     -61.000000       7.000000      31.000000
# 25%         2.000000      -4.000000      60.000000     366.000000
# 50%         4.000000      -1.000000      94.000000     640.000000
# 75%         5.000000      11.000000     144.000000    1044.000000
# max         7.000000    1457.000000     684.000000    4983.000000

# %% [markdown]
# The std deviation was 40 min with a mean of 12 min

# %% [markdown]
# Also: a quick look at the correlation between the numerical variables is extremely easy with pandas:

# %%
df.corr()
# Out:
#            DayOfWeek  DepDelay   AirTime  Distance
# DayOfWeek   1.000000 -0.018116  0.015865  0.021141
# DepDelay   -0.018116  1.000000  0.021388  0.020472
# AirTime     0.015865  0.021388  1.000000  0.977982
# Distance    0.021141  0.020472  0.977982  1.000000

# %% [markdown]
# ### A little taste of groupby
#
# Very often, we will want to split our data according to a variable, then compute some statistics on the different groups. We will see this in depth next week, but I want to give you a little taste.

# %% [markdown]
# What is the plane that has the highest average delay? We'll first group by tail number (the *license plate* of a plane) and then calculate the relevant statistic for each group (group of *departures*)

# %%
grouped_by_plane = df.groupby('TailNum')
grouped_by_plane['DepDelay'].mean().sort_values(ascending = False).head(10)
# Out:
# TailNum
# N771UA    505.000000
# N79011    262.000000
# N127UA    259.000000
# N854NW    235.500000
# N220UA    196.000000
# N3LMAA    192.000000
# N343NW    184.000000
# N78008    170.000000
# N1201P    133.666667
# N829MH    131.000000
# Name: DepDelay, dtype: float64

# %% [markdown]
# Oh, but those numbers smell like these planes had only a few, very delayed, departures! how can we count the number of departures *and* calculate the average delay at the same time?

# %%
functions = ['count','mean']
delays_by_plane = grouped_by_plane['DepDelay'].agg(functions)
delays_by_plane
# Out:
#          count        mean
# TailNum
# N001AA      57    1.842105
# N002AA      48    0.041667
# N003AA      53   27.169811
# N004AA      55    1.672727
# N005AA      48    3.875000
# N006AA      66   10.393939
# N007AA      55   31.018182
# N008AA      51   19.529412
# N009AA      45    4.733333
# N010AA      52   12.500000
# N011AA      64    3.937500
# N012AA      53    3.943396
# N013AA      42    2.309524
# N014AA      47   18.553191
# N015AA      41    0.731707
# N016AA      55   -1.163636
# N017AA      48    3.687500
# N018AA      49    2.510204
# N019AA      48    4.895833
# N020AA      59    2.864407
# N021AA      62   -1.129032
# N022AA      55   -2.672727
# N023AA      35   -0.914286
# N024AA      56    4.892857
# N025AA      44    6.590909
# N026AA      51    8.254902
# N027AA      65   15.830769
# N028AA      12  128.166667
# N0EGMQ      94   13.159574
# N102UW     106    9.084906
# ...        ...         ...
# N984DL     108   19.268519
# N985AT     139   25.769784
# N985DL     124   11.750000
# N986AT     145   12.420690
# N986CA      31   21.387097
# N986DL     109   13.477064
# N986SW     148   19.020270
# N987AT     156    8.583333
# N987DL     104    7.740385
# N988AT      31    9.096774
# N988CA     109   28.559633
# N988DL     105    8.057143
# N989AT     146   11.102740
# N989DL     108   11.055556
# N990AT     147    7.455782
# N990DL     117   10.700855
# N991AT     150    5.613333
# N991DL     124   14.403226
# N992DL     122    8.024590
# N993DL     107   11.775701
# N994AT     123   42.504065
# N994DL     105   18.761905
# N995AT     135    1.859259
# N995DL     102   13.421569
# N996DL     134    4.059701
# N997DL     123   11.341463
# N998AT     137   23.810219
# N998DL     130    3.538462
# N999DN     112   10.723214
# N9EAMQ     119   30.563025
#
# [4361 rows x 2 columns]

# %% [markdown]
# Awesome! now, let's look at the average delay of the planes with some departures (let's say, at least 15)

# %%
highly_delayed = a[a['count']>15]
highly_delayed.sort_values('mean', ascending = False).head(10)
# Out:
#          count       mean
# TailNum
# N73406      35  63.257143
# N382DA      46  62.695652
# N221FR     105  59.057143
# N213FR      61  58.836066
# N374HA      51  58.549020
# N892AT     129  58.534884
# N223FR      94  54.404255
# N203FR      64  52.781250
# N423SW     112  51.633929
# N12109      23  51.000000

# %%
df.join(highly_delayed, on = 'TailNum', how = 'inner')['Carrier'].unique()
# Out:
# array(['AS', 'DL', 'B6', 'EV', 'F9', 'HA', 'MQ', 'NK', 'AA', 'OO', 'US',
#        'VX', 'WN', 'UA'], dtype=object)

# %% [markdown]
# #### Exercise:
#
# Show cities by descending number of airports

# %%
grouped_by_city = df.groupby('OriginCityName')['Origin'].unique()
grouped_by_city.map(lambda x: len(x)).sort_values(ascending = False).head()
# Out:
# OriginCityName
# Chicago, IL       2
# Houston, TX       2
# New York, NY      2
# Washington, DC    2
# Fargo, ND         1
# Name: Origin, dtype: int64

# %% [markdown]
# ## Plotting
#
# There are several ways in which we could go about plotting this dataset in order to get acquainted with it.

# %% [markdown]
# For example, do the delays have a relationship with the number of departures a plane does?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

delays_by_plane.plot.scatter('mean','count', alpha = .1)

# %% [markdown]
# Pretty impossible to see anything in there. Maybe a different kind of plottting is required:

# %%
ax = delays_by_plane.plot.hexbin('mean','count')
ax.set_xlim(-20,240)
ax.set_ylim(-10,240)
# Out:
# (-10, 240)

# %% [markdown]
# What is the distribution of delays?

# %%
import seaborn as sns

hist_z = df['DepDelay'].hist(bins = 500)
hist_z.set_xlim(-100, 300)

plt.title('Number of flights per delay bin')

# %%
hist_z = df['DepDelay'].hist(bins = 500)
hist_z.set_xlim(-100, 300)
plt.yscale('log')

# %% [markdown]
# ### Another question:
#
# how do the delays stack over the course of the day? We are going to look at it by plotting the distribution of delays for each hour of the day. The very best way to compare distributions side by side is a boxplot, so we'll use that.

# %%
help(plt.boxplot)
# Out:
# Help on function boxplot in module matplotlib.pyplot:
#
# boxplot(x, notch=None, sym=None, vert=None, whis=None, positions=None, widths=None, patch_artist=None, bootstrap=None, usermedians=None, conf_intervals=None, meanline=None, showmeans=None, showcaps=None, showbox=None, showfliers=None, boxprops=None, labels=None, flierprops=None, medianprops=None, meanprops=None, capprops=None, whiskerprops=None, manage_xticks=True, autorange=False, zorder=None, hold=None, data=None)
#     Make a box and whisker plot.
#
#     Make a box and whisker plot for each column of ``x`` or each
#     vector in sequence ``x``.  The box extends from the lower to
#     upper quartile values of the data, with a line at the median.
#     The whiskers extend from the box to show the range of the
#     data.  Flier points are those past the end of the whiskers.
#
#     Parameters
#     ----------
#     x : Array or a sequence of vectors.
#         The input data.
#
#     notch : bool, optional (False)
#         If `True`, will produce a notched box plot. Otherwise, a
#         rectangular boxplot is produced. The notches represent the
#         confidence interval (CI) around the median. See the entry
#         for the ``bootstrap`` parameter for information regarding
#         how the locations of the notches are computed.
#
#         .. note::
#
#             In cases where the values of the CI are less than the
#             lower quartile or greater than the upper quartile, the
#             notches will extend beyond the box, giving it a
#             distinctive "flipped" appearance. This is expected
#             behavior and consistent with other statistical
#             visualization packages.
#
#     sym : str, optional
#         The default symbol for flier points. Enter an empty string
#         ('') if you don't want to show fliers. If `None`, then the
#         fliers default to 'b+'  If you want more control use the
#         flierprops kwarg.
#
#     vert : bool, optional (True)
#         If `True` (default), makes the boxes vertical. If `False`,
#         everything is drawn horizontally.
#
#     whis : float, sequence, or string (default = 1.5)
#         As a float, determines the reach of the whiskers to the beyond the
#         first and third quartiles. In other words, where IQR is the
#         interquartile range (`Q3-Q1`), the upper whisker will extend to
#         last datum less than `Q3 + whis*IQR`). Similarly, the lower whisker
#         will extend to the first datum greater than `Q1 - whis*IQR`.
#         Beyond the whiskers, data
#         are considered outliers and are plotted as individual
#         points. Set this to an unreasonably high value to force the
#         whiskers to show the min and max values. Alternatively, set
#         this to an ascending sequence of percentile (e.g., [5, 95])
#         to set the whiskers at specific percentiles of the data.
#         Finally, ``whis`` can be the string ``'range'`` to force the
#         whiskers to the min and max of the data.
#
#     bootstrap : int, optional
#         Specifies whether to bootstrap the confidence intervals
#         around the median for notched boxplots. If ``bootstrap`` is
#         None, no bootstrapping is performed, and notches are
#         calculated using a Gaussian-based asymptotic approximation
#         (see McGill, R., Tukey, J.W., and Larsen, W.A., 1978, and
#         Kendall and Stuart, 1967). Otherwise, bootstrap specifies
#         the number of times to bootstrap the median to determine its
#         95% confidence intervals. Values between 1000 and 10000 are
#         recommended.
#
#     usermedians : array-like, optional
#         An array or sequence whose first dimension (or length) is
#         compatible with ``x``. This overrides the medians computed
#         by matplotlib for each element of ``usermedians`` that is not
#         `None`. When an element of ``usermedians`` is None, the median
#         will be computed by matplotlib as normal.
#
#     conf_intervals : array-like, optional
#         Array or sequence whose first dimension (or length) is
#         compatible with ``x`` and whose second dimension is 2. When
#         the an element of ``conf_intervals`` is not None, the
#         notch locations computed by matplotlib are overridden
#         (provided ``notch`` is `True`). When an element of
#         ``conf_intervals`` is `None`, the notches are computed by the
#         method specified by the other kwargs (e.g., ``bootstrap``).
#
#     positions : array-like, optional
#         Sets the positions of the boxes. The ticks and limits are
#         automatically set to match the positions. Defaults to
#         `range(1, N+1)` where N is the number of boxes to be drawn.
#
#     widths : scalar or array-like
#         Sets the width of each box either with a scalar or a
#         sequence. The default is 0.5, or ``0.15*(distance between
#         extreme positions)``, if that is smaller.
#
#     patch_artist : bool, optional (False)
#         If `False` produces boxes with the Line2D artist. Otherwise,
#         boxes and drawn with Patch artists.
#
#     labels : sequence, optional
#         Labels for each dataset. Length must be compatible with
#         dimensions  of ``x``.
#
#     manage_xticks : bool, optional (True)
#         If the function should adjust the xlim and xtick locations.
#
#     autorange : bool, optional (False)
#         When `True` and the data are distributed such that the  25th and
#         75th percentiles are equal, ``whis`` is set to ``'range'`` such
#         that the whisker ends are at the minimum and maximum of the
#         data.
#
#     meanline : bool, optional (False)
#         If `True` (and ``showmeans`` is `True`), will try to render
#         the mean as a line spanning the full width of the box
#         according to ``meanprops`` (see below). Not recommended if
#         ``shownotches`` is also True. Otherwise, means will be shown
#         as points.
#
#     zorder : scalar, optional (None)
#         Sets the zorder of the boxplot.
#
#     Other Parameters
#     ----------------
#     showcaps : bool, optional (True)
#         Show the caps on the ends of whiskers.
#     showbox : bool, optional (True)
#         Show the central box.
#     showfliers : bool, optional (True)
#         Show the outliers beyond the caps.
#     showmeans : bool, optional (False)
#         Show the arithmetic means.
#     capprops : dict, optional (None)
#         Specifies the style of the caps.
#     boxprops : dict, optional (None)
#         Specifies the style of the box.
#     whiskerprops : dict, optional (None)
#         Specifies the style of the whiskers.
#     flierprops : dict, optional (None)
#         Specifies the style of the fliers.
#     medianprops : dict, optional (None)
#         Specifies the style of the median.
#     meanprops : dict, optional (None)
#         Specifies the style of the mean.
#
#     Returns
#     -------
#     result : dict
#       A dictionary mapping each component of the boxplot to a list
#       of the :class:`matplotlib.lines.Line2D` instances
#       created. That dictionary has the following keys (assuming
#       vertical boxplots):
#
#       - ``boxes``: the main body of the boxplot showing the
#         quartiles and the median's confidence intervals if
#         enabled.
#
#       - ``medians``: horizontal lines at the median of each box.
#
#       - ``whiskers``: the vertical lines extending to the most
#         extreme, non-outlier data points.
#
#       - ``caps``: the horizontal lines at the ends of the
#         whiskers.
#
#       - ``fliers``: points representing data that extend beyond
#         the whiskers (fliers).
#
#       - ``means``: points or lines representing the means.
#
#     Examples
#     --------
#     .. plot:: mpl_examples/statistics/boxplot_demo.py
#
#     .. note::
#         In addition to the above described arguments, this function can take a
#         **data** keyword argument. If such a **data** argument is given, the
#         following arguments are replaced by **data[<arg>]**:
#
#         * All positional and all keyword arguments.

# %% [markdown]
# We need to provide `plt.boxplot()` with a sequence that contains 24 elements. Each of those will be a sequence containing every individual delay for one hour of the day. We'll need, therefore, to extract hours of the day for each departure and group based on that.

# %%
df.head()
# Out:
#    DayOfWeek Carrier TailNum Origin   OriginCityName OriginStateName Dest  \
# 0          6      AS  N618AS    PDX     Portland, OR          Oregon  ANC
# 1          6      AS  N778AS    FAI    Fairbanks, AK          Alaska  SEA
# 2          6      AS  N586AS    ANC    Anchorage, AK          Alaska  PDX
# 3          6      AS  N615AS    PDX     Portland, OR          Oregon  ANC
# 4          6      AS  N471AS    LAX  Los Angeles, CA      California  ANC
#
#     DestCityName DestStateName  DepDelay  AirTime  Distance  \
# 0  Anchorage, AK        Alaska      19.0    195.0    1542.0
# 1    Seattle, WA    Washington     -13.0    197.0    1533.0
# 2   Portland, OR        Oregon      -8.0    192.0    1542.0
# 3  Anchorage, AK        Alaska      -9.0    193.0    1542.0
# 4  Anchorage, AK        Alaska       1.0    289.0    2345.0
#
#           DepDateTime FlightNum2
# 0 2015-02-07 09:59:00        131
# 1 2015-02-07 17:17:00        132
# 2 2015-02-07 11:32:00        140
# 3 2015-02-07 22:01:00        143
# 4 2015-02-07 19:41:00        149

# %%
df['hours']=df['DepDateTime'].map(lambda x: x.hour)

by_hour = df.groupby('hours')

hours = []
groups = []

for h,g in by_hour:
    hours.append("%02d" %h)
    groups.append(g['DepDelay'])

# %%
# We have create a groupby object. That object behaves like a list.
# Each element of that list is a (key, dataframe) tuple.
# You can think of the key as the group's name. The dataframe
# contains all the rows in the original dataframe that correspond 
# to that key: Here, group '0.0' contains all rows from flights 
# that departed on hour 0.

print(type(by_hour))
print(list(by_hour.head(10)))
print(list(by_hour)[0], list(by_hour)[1])
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'>
# ['DayOfWeek', 'Carrier', 'TailNum', 'Origin', 'OriginCityName', 'OriginStateName', 'Dest', 'DestCityName', 'DestStateName', 'DepDelay', 'AirTime', 'Distance', 'DepDateTime', 'FlightNum2', 'hours']
# (0.0,         DayOfWeek Carrier TailNum Origin                  OriginCityName  \
# 271             6      AS  N590AS    LIH                       Lihue, HI
# 330             7      AS  N558AS    SEA                     Seattle, WA
# 399             7      AS  N769AS    ANC                   Anchorage, AK
# 405             7      AS  N471AS    ANC                   Anchorage, AK
# 412             7      AS  N556AS    ANC                   Anchorage, AK
# 454             7      AS  N788AS    SFO               San Francisco, CA
# 461             7      AS  N622AS    SEA                     Seattle, WA
# 484             5      DL  N944DL    LGA                    New York, NY
# 695             5      DL  N922DL    MEM                     Memphis, TN
# 960             4      DL  N383DN    LAX                 Los Angeles, CA
# 991             4      DL  N127DL    SFO               San Francisco, CA
# 1065            4      DL  N589NW    LAX                 Los Angeles, CA
# 1119            4      DL  N339NB    ATL                     Atlanta, GA
# 1482            5      DL  N345NW    DEN                      Denver, CO
# 1589            5      DL  N144DA    SFO               San Francisco, CA
# 1793            5      DL  N690DL    SLC              Salt Lake City, UT
# 2161            5      DL  N3741S    ANC                   Anchorage, AK
# 2369            5      DL  N366NW    SLC              Salt Lake City, UT
# 2625            3      DL  N378DA    SLC              Salt Lake City, UT
# 2979            4      DL  N352NW    SLC              Salt Lake City, UT
# 3014            4      DL  N381DN    SLC              Salt Lake City, UT
# 3117            4      DL  N139DL    SEA                     Seattle, WA
# 3284            4      DL   N6702    DEN                      Denver, CO
# 3435            5      DL  N982DL    MEM                     Memphis, TN
# 3666            5      DL  N121DE    SFO               San Francisco, CA
# 3746            6      DL  N975DL    ATL                     Atlanta, GA
# 3787            6      DL  N371NW    SLC              Salt Lake City, UT
# 3804            6      DL  N349NW    SMF                  Sacramento, CA
# 3873            6      DL  N904DL    BWI                   Baltimore, MD
# 3892            6      DL  N919DN    DCA                  Washington, DC
# ...           ...     ...     ...    ...                             ...
# 428030          6      US     NaN    PHL                Philadelphia, PA
# 428031          6      US     NaN    PBI  West Palm Beach/Palm Beach, FL
# 428032          6      US     NaN    PHL                Philadelphia, PA
# 428066          6      US     NaN    DCA                  Washington, DC
# 428073          6      US     NaN    PHX                     Phoenix, AZ
# 428089          6      US     NaN    LAS                   Las Vegas, NV
# 428140          6      US  N904AW    OGG                     Kahului, HI
# 428143          6      US     NaN    SAN                   San Diego, CA
# 428154          3      OO  N8968E    MSP                 Minneapolis, MN
# 428236          1      OO  N446SW    CVG                  Cincinnati, OH
# 428333          1      OO  N438SW    SBN                  South Bend, IN
# 428392          2      OO  N461SW    ISN                   Williston, ND
# 428393          7      OO  N823AS    ISN                   Williston, ND
# 428497          4      OO  N631SK    SJC                    San Jose, CA
# 428575          1      OO  N779CA    CVG                  Cincinnati, OH
# 428683          7      OO  N445SW    CID      Cedar Rapids/Iowa City, IA
# 428841          6      OO  N8903A    ATL                     Atlanta, GA
# 428849          2      OO  N685BR    ATL                     Atlanta, GA
# 428870          7      OO  N442SW    ATL                     Atlanta, GA
# 428886          5      OO  N8965E    FWA                  Fort Wayne, IN
# 428889          6      OO  N461SW    FWA                  Fort Wayne, IN
# 428896          4      OO  N418SW    FWA                  Fort Wayne, IN
# 428953          2      OO     NaN    SUN   Sun Valley/Hailey/Ketchum, ID
# 429079          7      OO  N982SW    BIS             Bismarck/Mandan, ND
# 429095          7      OO  N776SK    CLE                   Cleveland, OH
# 429104          5      OO  N706SK    DEN                      Denver, CO
# 429115          7      OO  N679SA    ORD                     Chicago, IL
# 429132          5      OO  N765SK    SFO               San Francisco, CA
# 429165          6      OO  N751SK    ASE                       Aspen, CO
# 429182          1      OO  N742SK    BNA                   Nashville, TN
#
#        OriginStateName Dest                   DestCityName  DestStateName  \
# 271             Hawaii  SEA                    Seattle, WA     Washington
# 330         Washington  BOS                     Boston, MA  Massachusetts
# 399             Alaska  SEA                    Seattle, WA     Washington
# 405             Alaska  SEA                    Seattle, WA     Washington
# 412             Alaska  PDX                   Portland, OR         Oregon
# 454         California  PSP               Palm Springs, CA     California
# 461         Washington  SFO              San Francisco, CA     California
# 484           New York  MSY                New Orleans, LA      Louisiana
# 695          Tennessee  ATL                    Atlanta, GA        Georgia
# 960         California  MEM                    Memphis, TN      Tennessee
# 991         California  MSP                Minneapolis, MN      Minnesota
# 1065        California  MSP                Minneapolis, MN      Minnesota
# 1119           Georgia  CRW          Charleston/Dunbar, WV  West Virginia
# 1482          Colorado  LGA                   New York, NY       New York
# 1589        California  ATL                    Atlanta, GA        Georgia
# 1793              Utah  JFK                   New York, NY       New York
# 2161            Alaska  SEA                    Seattle, WA     Washington
# 2369              Utah  DTW                    Detroit, MI       Michigan
# 2625              Utah  JFK                   New York, NY       New York
# 2979              Utah  ATL                    Atlanta, GA        Georgia
# 3014              Utah  JFK                   New York, NY       New York
# 3117        Washington  MSP                Minneapolis, MN      Minnesota
# 3284          Colorado  ATL                    Atlanta, GA        Georgia
# 3435         Tennessee  ATL                    Atlanta, GA        Georgia
# 3666        California  MSP                Minneapolis, MN      Minnesota
# 3746           Georgia  BWI                  Baltimore, MD       Maryland
# 3787              Utah  DTW                    Detroit, MI       Michigan
# 3804        California  MSP                Minneapolis, MN      Minnesota
# 3873          Maryland  ATL                    Atlanta, GA        Georgia
# 3892          Virginia  ATL                    Atlanta, GA        Georgia
# ...                ...  ...                            ...            ...
# 428030    Pennsylvania  DFW          Dallas/Fort Worth, TX          Texas
# 428031         Florida  PHL               Philadelphia, PA   Pennsylvania
# 428032    Pennsylvania  BOS                     Boston, MA  Massachusetts
# 428066        Virginia  PHX                    Phoenix, AZ        Arizona
# 428073         Arizona  DCA                 Washington, DC       Virginia
# 428089          Nevada  PHL               Philadelphia, PA   Pennsylvania
# 428140          Hawaii  PHX                    Phoenix, AZ        Arizona
# 428143      California  PHL               Philadelphia, PA   Pennsylvania
# 428154       Minnesota  MOT                      Minot, ND   North Dakota
# 428236        Kentucky  BNA                  Nashville, TN      Tennessee
# 428333         Indiana  ATL                    Atlanta, GA        Georgia
# 428392    North Dakota  MSP                Minneapolis, MN      Minnesota
# 428393    North Dakota  MSP                Minneapolis, MN      Minnesota
# 428497      California  LAX                Los Angeles, CA     California
# 428575        Kentucky  BNA                  Nashville, TN      Tennessee
# 428683            Iowa  ATL                    Atlanta, GA        Georgia
# 428841         Georgia  SBN                 South Bend, IN        Indiana
# 428849         Georgia  SBN                 South Bend, IN        Indiana
# 428870         Georgia  FWA                 Fort Wayne, IN        Indiana
# 428886         Indiana  ATL                    Atlanta, GA        Georgia
# 428889         Indiana  ATL                    Atlanta, GA        Georgia
# 428896         Indiana  ATL                    Atlanta, GA        Georgia
# 428953           Idaho  SLC             Salt Lake City, UT           Utah
# 429079    North Dakota  DEN                     Denver, CO       Colorado
# 429095            Ohio  ORD                    Chicago, IL       Illinois
# 429104        Colorado  JAC                    Jackson, WY        Wyoming
# 429115        Illinois  PIA                     Peoria, IL       Illinois
# 429132      California  SUN  Sun Valley/Hailey/Ketchum, ID          Idaho
# 429165        Colorado  IAH                    Houston, TX          Texas
# 429182       Tennessee  IAH                    Houston, TX          Texas
#
#         DepDelay  AirTime  Distance         DepDateTime FlightNum2  hours
# 271         11.0    296.0    2701.0 2015-02-07 00:06:00        816    0.0
# 330          NaN      NaN    2496.0 2015-02-08 00:00:00         24    0.0
# 399          4.0    183.0    1448.0 2015-02-08 00:09:00         98    0.0
# 405         -1.0    179.0    1448.0 2015-02-08 00:44:00        108    0.0
# 412        -10.0    198.0    1542.0 2015-02-08 00:40:00        122    0.0
# 454          NaN      NaN     421.0 2015-02-08 00:00:00        306    0.0
# 461          NaN      NaN     679.0 2015-02-08 00:00:00        318    0.0
# 484          NaN      NaN    1183.0 2015-02-20 00:00:00       1805    0.0
# 695          NaN      NaN     332.0 2015-02-20 00:00:00       1974    0.0
# 960         -5.0    176.0    1619.0 2015-02-19 00:57:00        765    0.0
# 991        -11.0    181.0    1589.0 2015-02-19 00:19:00        806    0.0
# 1065         0.0    177.0    1535.0 2015-02-19 00:40:00        892    0.0
# 1119       205.0     58.0     363.0 2015-02-19 00:01:00        993    0.0
# 1482        -6.0    177.0    1620.0 2015-02-20 00:46:00        922    0.0
# 1589       117.0    216.0    2139.0 2015-02-20 00:40:00       1099    0.0
# 1793        38.0    211.0    1990.0 2015-02-20 00:18:00       1264    0.0
# 2161        -6.0    161.0    1448.0 2015-02-20 00:34:00       1560    0.0
# 2369        -5.0    159.0    1481.0 2015-02-20 00:25:00       1722    0.0
# 2625        -9.0    230.0    1990.0 2015-02-18 00:51:00       2354    0.0
# 2979        -5.0    172.0    1590.0 2015-02-19 00:54:00       2324    0.0
# 3014        -6.0    225.0    1990.0 2015-02-19 00:54:00       2354    0.0
# 3117        -7.0    153.0    1399.0 2015-02-19 00:43:00       2440    0.0
# 3284         6.0    122.0    1199.0 2015-02-19 00:21:00       2579    0.0
# 3435         NaN      NaN     332.0 2015-02-20 00:00:00         82    0.0
# 3666         2.0    176.0    1589.0 2015-02-20 00:32:00        806    0.0
# 3746         NaN      NaN     577.0 2015-02-21 00:00:00       1678    0.0
# 3787         0.0    165.0    1481.0 2015-02-21 00:30:00       1722    0.0
# 3804        -2.0    179.0    1517.0 2015-02-21 00:03:00       1745    0.0
# 3873         NaN      NaN     577.0 2015-02-21 00:00:00       1824    0.0
# 3892         NaN      NaN     547.0 2015-02-21 00:00:00       1839    0.0
# ...          ...      ...       ...                 ...        ...    ...
# 428030       NaN      NaN    1303.0 2015-02-21 00:00:00        557    0.0
# 428031       NaN      NaN     951.0 2015-02-21 00:00:00        558    0.0
# 428032       NaN      NaN     280.0 2015-02-21 00:00:00        558    0.0
# 428066       NaN      NaN    1979.0 2015-02-21 00:00:00        589    0.0
# 428073       NaN      NaN    1979.0 2015-02-21 00:00:00        595    0.0
# 428089       NaN      NaN    2176.0 2015-02-21 00:00:00        607    0.0
# 428140      32.0    333.0    2845.0 2015-02-21 00:02:00        645    0.0
# 428143       NaN      NaN    2370.0 2015-02-21 00:00:00        648    0.0
# 428154       NaN      NaN     449.0 2015-02-04 00:00:00       4743    0.0
# 428236       NaN      NaN     230.0 2015-02-16 00:00:00       4746    0.0
# 428333       NaN      NaN     566.0 2015-02-02 00:00:00       4827    0.0
# 428392       NaN      NaN     546.0 2015-02-10 00:00:00       4830    0.0
# 428393       NaN      NaN     546.0 2015-02-15 00:00:00       4830    0.0
# 428497       NaN      NaN     308.0 2015-02-05 00:00:00       4832    0.0
# 428575       NaN      NaN     230.0 2015-02-16 00:00:00       4834    0.0
# 428683       NaN      NaN     694.0 2015-02-01 00:00:00       4839    0.0
# 428841       NaN      NaN     566.0 2015-02-14 00:00:00       4848    0.0
# 428849       NaN      NaN     566.0 2015-02-24 00:00:00       4848    0.0
# 428870       NaN      NaN     508.0 2015-02-22 00:00:00       4849    0.0
# 428886       NaN      NaN     508.0 2015-02-13 00:00:00       4850    0.0
# 428889       NaN      NaN     508.0 2015-02-28 00:00:00       4850    0.0
# 428896       NaN      NaN     508.0 2015-02-26 00:00:00       4850    0.0
# 428953       NaN      NaN     222.0 2015-02-03 00:00:00       4854    0.0
# 429079       NaN      NaN     516.0 2015-02-22 00:00:00       4965    0.0
# 429095       NaN      NaN     315.0 2015-02-01 00:00:00       4965    0.0
# 429104       NaN      NaN     406.0 2015-02-20 00:00:00       4965    0.0
# 429115       NaN      NaN     130.0 2015-02-01 00:00:00       4965    0.0
# 429132       NaN      NaN     587.0 2015-02-06 00:00:00       4966    0.0
# 429165       NaN      NaN     913.0 2015-02-21 00:00:00       4967    0.0
# 429182       NaN      NaN     657.0 2015-02-16 00:00:00       4967    0.0
#
# [21371 rows x 15 columns]) (1.0,         DayOfWeek Carrier TailNum Origin      OriginCityName OriginStateName  \
# 417             7      AS  N413AS    FAI       Fairbanks, AK          Alaska
# 2020            5      DL  N139DL    LAS       Las Vegas, NV          Nevada
# 2267            5      DL   N6701    PHX         Phoenix, AZ         Arizona
# 2590            3      DL  N6715C    SLC  Salt Lake City, UT            Utah
# 3078            4      DL  N137DL    PHX         Phoenix, AZ         Arizona
# 3635            5      DL   N3766    LAX     Los Angeles, CA      California
# 4497            5      DL  N127DL    PHX         Phoenix, AZ         Arizona
# 4922            7      DL  N953DL    DTW         Detroit, MI        Michigan
# 5619            7      DL  N823DN    PHX         Phoenix, AZ         Arizona
# 6063            6      DL  N590NW    LAX     Los Angeles, CA      California
# 6360            6      DL  N939DL    MSP     Minneapolis, MN       Minnesota
# 6714            6      DL  N681DA    PHX         Phoenix, AZ         Arizona
# 7007            7      DL   N3752    LAS       Las Vegas, NV          Nevada
# 7573            6      DL  N6708D    SLC  Salt Lake City, UT            Utah
# 7575            6      DL  N927DN    BWI       Baltimore, MD        Maryland
# 7634            6      DL  N320US    PHX         Phoenix, AZ         Arizona
# 8164            1      DL  N687DL    PHX         Phoenix, AZ         Arizona
# 8885            1      DL  N988AT    MSP     Minneapolis, MN       Minnesota
# 9277            1      DL  N3744F    LAX     Los Angeles, CA      California
# 9399            1      DL  N357NW    DEN          Denver, CO        Colorado
# 10677           7      DL   N6709    SLC  Salt Lake City, UT            Utah
# 10765           7      DL  N138DL    PHX         Phoenix, AZ         Arizona
# 11103           1      DL  N137DL    PHX         Phoenix, AZ         Arizona
# 11655           2      DL  N3744F    LAX     Los Angeles, CA      California
# 12590           7      B6  N715JB    SJU        San Juan, PR     Puerto Rico
# 14117           1      DL  N589NW    LAS       Las Vegas, NV          Nevada
# 14262           1      DL  N975AT    DTW         Detroit, MI        Michigan
# 14714           1      DL  N892AT    MSP     Minneapolis, MN       Minnesota
# 15004           4      DL  N6707A    PHX         Phoenix, AZ         Arizona
# 16167           3      DL  N618DL    PHX         Phoenix, AZ         Arizona
# ...           ...     ...     ...    ...                 ...             ...
# 407851          3      US  N669AW    CLT       Charlotte, NC  North Carolina
# 410890          3      US  N554UW    DEN          Denver, CO        Colorado
# 411204          5      US  N197UW    DEN          Denver, CO        Colorado
# 412038          4      US  N570UW    DEN          Denver, CO        Colorado
# 412600          6      US  N936UW    HNL        Honolulu, HI          Hawaii
# 413049          6      US  N553UW    DEN          Denver, CO        Colorado
# 415613          1      US  N524UW    DEN          Denver, CO        Colorado
# 417307          1      UA  N29717    PHX         Phoenix, AZ         Arizona
# 417445          4      US  N547UW    DEN          Denver, CO        Colorado
# 418081          5      US  N562UW    PHX         Phoenix, AZ         Arizona
# 418312          5      US  N189UW    PHX         Phoenix, AZ         Arizona
# 418616          3      US  N585UW    DEN          Denver, CO        Colorado
# 419444          5      US  N103US    PHX         Phoenix, AZ         Arizona
# 419532          5      US  N180US    DEN          Denver, CO        Colorado
# 419642          5      US  N126UW    PHL    Philadelphia, PA    Pennsylvania
# 419831          5      US  N184US    PHX         Phoenix, AZ         Arizona
# 420039          6      US  N569UW    PHX         Phoenix, AZ         Arizona
# 420051          6      US  N906AW    KOA            Kona, HI          Hawaii
# 420092          6      US  N560UW    PHX         Phoenix, AZ         Arizona
# 420250          6      US  N545UW    DEN          Denver, CO        Colorado
# 420570          6      US  N542UW    PHX         Phoenix, AZ         Arizona
# 421359          1      US  N171US    DEN          Denver, CO        Colorado
# 422451          7      US  N552UW    DEN          Denver, CO        Colorado
# 423370          6      US  N642AW    PHX         Phoenix, AZ         Arizona
# 423396          6      US  N767UW    ANC       Anchorage, AK          Alaska
# 423428          6      US  N918US    PHX         Phoenix, AZ         Arizona
# 424009          2      US  N198UW    DEN          Denver, CO        Colorado
# 425980          4      US  N161UW    DEN          Denver, CO        Colorado
# 426015          4      US  N951UW    PHL    Philadelphia, PA    Pennsylvania
# 427115          3      US  N192UW    DEN          Denver, CO        Colorado
#
#        Dest     DestCityName   DestStateName  DepDelay  AirTime  Distance  \
# 417     SEA      Seattle, WA      Washington     -11.0    187.0    1533.0
# 2020    MSP  Minneapolis, MN       Minnesota      15.0    144.0    1299.0
# 2267    ATL      Atlanta, GA         Georgia      -2.0    162.0    1587.0
# 2590    ATL      Atlanta, GA         Georgia       1.0    169.0    1590.0
# 3078    MSP  Minneapolis, MN       Minnesota      -5.0    156.0    1276.0
# 3635    MEM      Memphis, TN       Tennessee      -1.0    173.0    1619.0
# 4497    MSP  Minneapolis, MN       Minnesota     -10.0    145.0    1276.0
# 4922    MSP  Minneapolis, MN       Minnesota     352.0     84.0     528.0
# 5619    ATL      Atlanta, GA         Georgia      -4.0    167.0    1587.0
# 6063    MSP  Minneapolis, MN       Minnesota      25.0    183.0    1535.0
# 6360    MCI  Kansas City, MO        Missouri     345.0     61.0     393.0
# 6714    ATL      Atlanta, GA         Georgia      34.0    159.0    1587.0
# 7007    DTW      Detroit, MI        Michigan     121.0    181.0    1749.0
# 7573    ATL      Atlanta, GA         Georgia      45.0    162.0    1590.0
# 7575    ATL      Atlanta, GA         Georgia     688.0     89.0     577.0
# 7634    MSP  Minneapolis, MN       Minnesota      -4.0    146.0    1276.0
# 8164    ATL      Atlanta, GA         Georgia      29.0    165.0    1587.0
# 8885    DLH       Duluth, MN       Minnesota     223.0     33.0     144.0
# 9277    MEM      Memphis, TN       Tennessee      28.0    177.0    1619.0
# 9399    LGA     New York, NY        New York      24.0    161.0    1620.0
# 10677   ATL      Atlanta, GA         Georgia      54.0    160.0    1590.0
# 10765   MSP  Minneapolis, MN       Minnesota       2.0    145.0    1276.0
# 11103   MSP  Minneapolis, MN       Minnesota       0.0    146.0    1276.0
# 11655   MEM      Memphis, TN       Tennessee      -1.0    166.0    1619.0
# 12590   TPA        Tampa, FL         Florida     263.0    166.0    1237.0
# 14117   MSP  Minneapolis, MN       Minnesota      15.0    161.0    1299.0
# 14262   BNA    Nashville, TN       Tennessee     248.0     72.0     456.0
# 14714   CLT    Charlotte, NC  North Carolina     378.0    104.0     930.0
# 15004   ATL      Atlanta, GA         Georgia       0.0    173.0    1587.0
# 16167   ATL      Atlanta, GA         Georgia      -3.0    173.0    1587.0
# ...     ...              ...             ...       ...      ...       ...
# 407851  IAH      Houston, TX           Texas     311.0    129.0     912.0
# 410890  CLT    Charlotte, NC  North Carolina       0.0    150.0    1337.0
# 411204  CLT    Charlotte, NC  North Carolina      -2.0    153.0    1337.0
# 412038  CLT    Charlotte, NC  North Carolina       4.0    146.0    1337.0
# 412600  PHX      Phoenix, AZ         Arizona     129.0    308.0    2917.0
# 413049  CLT    Charlotte, NC  North Carolina      -8.0    158.0    1337.0
# 415613  CLT    Charlotte, NC  North Carolina      -4.0    147.0    1337.0
# 417307  EWR       Newark, NJ      New Jersey       6.0    238.0    2133.0
# 417445  CLT    Charlotte, NC  North Carolina      -7.0    151.0    1337.0
# 418081  ATL      Atlanta, GA         Georgia       3.0    191.0    1587.0
# 418312  ORD      Chicago, IL        Illinois      -4.0    186.0    1440.0
# 418616  CLT    Charlotte, NC  North Carolina      -7.0    144.0    1337.0
# 419444  TPA        Tampa, FL         Florida      -1.0    215.0    1788.0
# 419532  CLT    Charlotte, NC  North Carolina      -5.0    159.0    1337.0
# 419642  BOS       Boston, MA   Massachusetts     352.0     46.0     280.0
# 419831  MSP  Minneapolis, MN       Minnesota      -9.0    166.0    1276.0
# 420039  BWI    Baltimore, MD        Maryland      12.0    235.0    1999.0
# 420051  PHX      Phoenix, AZ         Arizona      89.0    324.0    2860.0
# 420092  ORD      Chicago, IL        Illinois       0.0    181.0    1440.0
# 420250  CLT    Charlotte, NC  North Carolina     -10.0    152.0    1337.0
# 420570  MSP  Minneapolis, MN       Minnesota      -2.0    155.0    1276.0
# 421359  CLT    Charlotte, NC  North Carolina      -6.0    150.0    1337.0
# 422451  CLT    Charlotte, NC  North Carolina      -5.0    143.0    1337.0
# 423370  MSP  Minneapolis, MN       Minnesota     107.0    145.0    1276.0
# 423396  PHX      Phoenix, AZ         Arizona      -3.0    305.0    2552.0
# 423428  ATL      Atlanta, GA         Georgia      -6.0    186.0    1587.0
# 424009  CLT    Charlotte, NC  North Carolina      -2.0    149.0    1337.0
# 425980  CLT    Charlotte, NC  North Carolina      -6.0    142.0    1337.0
# 426015  PIT   Pittsburgh, PA    Pennsylvania     270.0     50.0     268.0
# 427115  CLT    Charlotte, NC  North Carolina      -4.0    146.0    1337.0
#
#                DepDateTime FlightNum2  hours
# 417    2015-02-08 01:04:00        130    1.0
# 2020   2015-02-20 01:10:00       1450    1.0
# 2267   2015-02-20 01:09:00       1646    1.0
# 2590   2015-02-18 01:00:00       2324    1.0
# 3078   2015-02-19 01:10:00       2408    1.0
# 3635   2015-02-20 01:01:00        765    1.0
# 4497   2015-02-20 01:05:00       2408    1.0
# 4922   2015-02-22 01:32:00       1055    1.0
# 5619   2015-02-22 01:07:00       1646    1.0
# 6063   2015-02-21 01:05:00        892    1.0
# 6360   2015-02-21 01:47:00       1275    1.0
# 6714   2015-02-21 01:45:00       1646    1.0
# 7007   2015-02-22 01:41:00       1979    1.0
# 7573   2015-02-21 01:44:00       2324    1.0
# 7575   2015-02-21 01:13:00       2325    1.0
# 7634   2015-02-21 01:11:00       2408    1.0
# 8164   2015-02-23 01:40:00       1646    1.0
# 8885   2015-02-23 01:28:00       2230    1.0
# 9277   2015-02-23 01:30:00        765    1.0
# 9399   2015-02-23 01:16:00        922    1.0
# 10677  2015-02-22 01:53:00       2324    1.0
# 10765  2015-02-22 01:17:00       2408    1.0
# 11103  2015-02-23 01:15:00       2408    1.0
# 11655  2015-02-24 01:01:00        765    1.0
# 12590  2015-02-22 01:08:00        552    1.0
# 14117  2015-02-02 01:00:00       1450    1.0
# 14262  2015-02-02 01:48:00       1565    1.0
# 14714  2015-02-02 01:53:00       1936    1.0
# 15004  2015-02-26 01:11:00       1646    1.0
# 16167  2015-02-25 01:08:00       1646    1.0
# ...                    ...        ...    ...
# 407851 2015-02-04 01:36:00        673    1.0
# 410890 2015-02-04 01:20:00        469    1.0
# 411204 2015-02-06 01:18:00        469    1.0
# 412038 2015-02-05 01:24:00        469    1.0
# 412600 2015-02-07 01:24:00        693    1.0
# 413049 2015-02-07 01:12:00       1963    1.0
# 415613 2015-02-09 01:16:00        469    1.0
# 417307 2015-02-02 01:21:00       1122    1.0
# 417445 2015-02-12 01:13:00       1813    1.0
# 418081 2015-02-13 01:18:00        517    1.0
# 418312 2015-02-13 01:16:00        702    1.0
# 418616 2015-02-11 01:13:00        469    1.0
# 419444 2015-02-13 01:04:00       1760    1.0
# 419532 2015-02-13 01:15:00       1813    1.0
# 419642 2015-02-13 01:07:00       1888    1.0
# 419831 2015-02-13 01:16:00       2021    1.0
# 420039 2015-02-14 01:07:00        655    1.0
# 420051 2015-02-14 01:14:00        664    1.0
# 420092 2015-02-14 01:20:00        702    1.0
# 420250 2015-02-14 01:10:00       1725    1.0
# 420570 2015-02-14 01:23:00       2021    1.0
# 421359 2015-02-16 01:14:00       1813    1.0
# 422451 2015-02-15 01:15:00       1725    1.0
# 423370 2015-02-14 01:46:00        467    1.0
# 423396 2015-02-14 01:52:00        489    1.0
# 423428 2015-02-14 01:09:00        517    1.0
# 424009 2015-02-17 01:18:00       1813    1.0
# 425980 2015-02-19 01:14:00       1813    1.0
# 426015 2015-02-19 01:05:00       1838    1.0
# 427115 2015-02-18 01:16:00       1813    1.0
#
# [548 rows x 15 columns])

# %% [markdown]
# ### Everything looks ok! let's plot this thing!

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.set_ylim(-20, 240)

bp = plt.boxplot(groups)

labels = plt.setp(ax1, xticklabels=hours)
# Out:
# /home/dsc/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:4269: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# /home/dsc/anaconda3/lib/python3.6/site-packages/matplotlib/cbook.py:2066: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = np.compress(x <= hival, x)
# /home/dsc/anaconda3/lib/python3.6/site-packages/matplotlib/cbook.py:2073: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = np.compress(x >= loval, x)
# /home/dsc/anaconda3/lib/python3.6/site-packages/matplotlib/cbook.py:2081: RuntimeWarning: invalid value encountered in less
#   np.compress(x < stats['whislo'], x),
# /home/dsc/anaconda3/lib/python3.6/site-packages/matplotlib/cbook.py:2082: RuntimeWarning: invalid value encountered in greater
#   np.compress(x > stats['whishi'], x)
